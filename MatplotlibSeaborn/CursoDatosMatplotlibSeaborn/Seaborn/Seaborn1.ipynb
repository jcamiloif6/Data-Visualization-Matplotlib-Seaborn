# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_theme(style="darkgrid", context="notebook")

relation = sns.relplot(data=penguins, height=7, aspect=1.2,
                       markers=["s",".","p","d"])
relation.set(title="Analisis de Pinguino")
relation.set_ylabels("Variables")
relation.set_xlabels("Numero de Pinguinos")
#plt.grid(False)
plt.show()

# %%
print(">>>>>>>>>>>>>>> SIMPLE")

sns.relplot(data=penguins, x="bill_length_mm", y="flipper_length_mm")
plt.show()

print(">>>>>>>>>>>>>>> MATIZ Y TAMAÑO")

sns.relplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
            hue="body_mass_g", s=150)
plt.show()

sns.relplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
            hue="species", s=150)
plt.show()

print(">>>>>>>>>>>>>>> REJILLA, TAMAÑO PERSONALIZADO Y ESTILO")

sns.relplot(data=penguins,
            x="bill_length_mm",
            y='flipper_length_mm',
            hue="species",
            row="sex",
            size="body_mass_g",
            sizes=(100,500),
            style="sex")
plt.show()

sns.relplot(data=penguins,
            x="bill_length_mm",
            y='flipper_length_mm',
            hue="species",
            col="island",
            row="sex",
            size="body_mass_g",
            sizes=(100,500),
            style="sex")
plt.show()
# Out:
# >>>>>>>>>>>>>>> SIMPLE
# >>>>>>>>>>>>>>> MATIZ Y TAMAÑO
# >>>>>>>>>>>>>>> REJILLA, TAMAÑO PERSONALIZADO Y ESTILO

# %% [markdown]
# **GRAFICO DE LINEAS**

# %%
sns.relplot(data=penguins,
            x="species",
            y="body_mass_g",
            kind="line",
            hue="sex",
            style="sex",
            ci="sd")

plt.show()

sns.relplot(data=penguins,
            x="bill_depth_mm",
            y="flipper_length_mm",
            kind="line",
            hue="species",
            style="species",
            ci=99)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 99)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## **COMBINANDO GRAFICOS**

# %% [markdown]
# **Lineas y Dispersion**

# %%
figura, ejes = plt.subplots(1,2,figsize=(15,5))

sns.lineplot(data=penguins,
            x="species",
            y="body_mass_g",
            hue="sex",
            style="sex",
            errorbar='sd',
            ax=ejes[0])

sns.scatterplot(data=penguins, x="bill_length_mm", y="flipper_length_mm",
            hue="species", s=150, ax=ejes[1])

plt.show()
